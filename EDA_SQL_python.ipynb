# %%
# !pip install ipython-sql
# !pip install seaborn
import seaborn as sns
# %load_ext sql

# %%
import sqlite3 as sq
import csv

# %%
conn = sq.connect('economic.db')
cur = conn.cursor()

# %% [markdown]
# ## **Used for connecting sqlite3 database with jupyter notebook**

# %%
# %sql sqlite:///economic.db

# %%
import pandas
df = pandas.read_csv('https://data.cityofchicago.org/resource/jcxq-k9xf.csv')

# %%
df.to_sql('economic' , conn , if_exists = 'replace') # it gives you the number of rows in return
# Out:
# 78

# %%
# Install the 'ipython-sql' and 'prettytable' libraries using pip
# !pip install ipython-sql prettytable

# Import the 'prettytable' library, which is used to display data in a formatted table
import prettytable

# Set the default display format for prettytable to 'DEFAULT' (i.e., a simple table format)
prettytable.DEFAULT = 'DEFAULT'

# %%
# %sql select * from economic;
# Out:
#  * sqlite:///economic.db
# Done.
# [(0, 1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (1, 2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (2, 3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (3, 4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (4, 5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0),
#  (5, 6.0, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17.0, 60058, 5.0),
#  (6, 7.0, 'Lincoln Park', 0.8, 12.3, 5.1, 3.6, 21.5, 71551, 2.0),
#  (7, 8.0, 'Near North Side', 1.9, 12.9, 7.0, 2.5, 22.6, 88669, 1.0),
#  (8, 9.0, 'Edison Park', 1.1, 3.3, 6.5, 7.4, 35.3, 40959, 8.0),
#  (9, 10.0, 'Norwood Park', 2.0, 5.4, 9.0, 11.5, 39.5, 32875, 21.0),
#  (10, 11.0, 'Jefferson Park', 2.7, 8.6, 12.4, 13.4, 35.5, 27751, 25.0),
#  (11, 12.0, 'Forest Glen', 1.1, 7.5, 6.8, 4.9, 40.5, 44164, 11.0),
#  (12, 13.0, 'North Park', 3.9, 13.2, 9.9, 14.4, 39.0, 26576, 33.0),
# ...

# %%
per_capita_income_ is related to percent_households_below_poverty and percent_aged_16_unemployed

# %%
perc_per_16 = %sql select per_capita_income_ , percent_aged_16_unemployed from economic;
# Out:
#  * sqlite:///economic.db
# Done.

# %%
sns.jointplot(x = 'per_capita_income_' , y = 'percent_aged_16_unemployed' , data = perc_per_16.DataFrame())
# Out:
# /home/shahbaz-baig/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/shahbaz-baig/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
perc_per_16
# Out:
# [(23939, 8.7),
#  (23040, 8.8),
#  (35787, 8.9),
#  (37524, 8.2),
#  (57123, 5.2),
#  (60058, 4.7),
#  (71551, 5.1),
#  (88669, 7.0),
#  (40959, 6.5),
#  (32875, 9.0),
#  (27751, 12.4),
#  (44164, 6.8),
#  (26576, 9.9),
#  (21323, 10.0),
#  (24336, 12.6),
#  (27249, 10.0),
#  (26282, 10.0),
#  (22014, 13.8),
#  (15461, 14.6),
#  (15089, 13.1),
#  (20039, 9.2),
#  (31908, 8.2),
#  (13781, 17.3),
#  (43198, 6.6),
#  (15957, 22.6),
#  (10934, 25.8),
#  (12961, 19.6),
#  (44689, 10.7),
#  (12034, 21.2),
#  (10402, 15.8),
#  (16444, 15.8),
#  (65526, 5.7),
#  (59077, 4.9),
#  (16148, 16.7),
#  (23791, 18.2),
#  (19252, 28.7),
#  (10432, 33.9),
#  (23472, 24.3),
#  (35911, 15.7),
#  (13785, 28.6),
#  (39056, 8.4),
#  (18672, 23.4),
#  (19398, 20.0),
#  (18881, 24.0),
#  (24454, 21.1),
#  (16579, 19.7),
#  (12515, 18.6),
#  (28887, 20.0),
#  (17949, 20.3),
#  (20588, 22.8),
#  (14685, 16.3),
#  (17104, 12.1),
#  (16563, 19.4),
#  (8201, 34.6),
#  (22677, 9.6),
#  (26353, 11.3),
# ...

# %%
per_hard = %sql select per_capita_income_ , hardship_index from economic;
sns.jointplot(x = 'per_capita_income_' , y = 'hardship_index' , data = per_hard.DataFrame())
# plt.show()
# Out:
#  * sqlite:///economic.db
# Done.
# /home/shahbaz-baig/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/shahbaz-baig/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
